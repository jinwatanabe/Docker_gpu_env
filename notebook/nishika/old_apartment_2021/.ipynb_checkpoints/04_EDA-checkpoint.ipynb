# %%
import pandas as pd
from input_data import input_df
import scipy.stats
import matplotlib.pyplot as plt
from pre4 import data_pre
from m01_lightgbm import train
pd.set_option('display.max_rows', 150)
# Out:
# <style type='text/css'>
# .datatable table.frame { margin-bottom: 0; }
# .datatable table.frame thead { border-bottom: none; }
# .datatable table.frame tr.coltypes td {  color: #FFFFFF;  line-height: 6px;  padding: 0 0.5em;}
# .datatable .bool    { background: #DDDD99; }
# .datatable .object  { background: #565656; }
# .datatable .int     { background: #5D9E5D; }
# .datatable .float   { background: #4040CC; }
# .datatable .str     { background: #CC4040; }
# .datatable .row_index {  background: var(--jp-border-color3);  border-right: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  font-size: 9px;}
# .datatable .frame tr.coltypes .row_index {  background: var(--jp-border-color0);}
# .datatable th:nth-child(2) { padding-left: 12px; }
# .datatable .hellipsis {  color: var(--jp-cell-editor-border-color);}
# .datatable .vellipsis {  background: var(--jp-layout-color0);  color: var(--jp-cell-editor-border-color);}
# .datatable .na {  color: var(--jp-cell-editor-border-color);  font-size: 80%;}
# .datatable .footer { font-size: 9px; }
# .datatable .frame_dimensions {  background: var(--jp-border-color3);  border-top: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  display: inline-block;  opacity: 0.6;  padding: 1px 10px 1px 5px;}
# </style>

# %%
df = input_df()
# Out:
# /opt/conda/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3357: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):

# %%
df = data_pre(df)

# %%
df.head()
# Out:
#         都道府県名 市区町村名   地区名 最寄駅：名称  最寄駅：距離（分）   間取り  面積（㎡）   建築年 建物の構造  用途  ...  \
# ID                                                                        ...
# 1117225   北海道  苫小牧市  新中野町    苫小牧       25.0  ３ＬＤＫ  120.0  12.0    ＲＣ  住宅  ...
# 1114724   北海道  苫小牧市   青葉町     青葉        9.0  ３ＬＤＫ   70.0  35.0    ＲＣ  住宅  ...
# 1114753   北海道  苫小牧市   青葉町     青葉        3.0  ３ＬＤＫ   70.0  31.0    ＲＣ  住宅  ...
# 1120806   北海道  苫小牧市    表町    苫小牧        8.0  ４ＬＤＫ  105.0  18.0    ＲＣ  住宅  ...
# 1117264   北海道  苫小牧市  新中野町    苫小牧       25.0  ３ＬＤＫ   90.0  15.0    ＲＣ  住宅  ...
#
#                  都市計画 建ぺい率（％）  容積率（％）     取引時点   改装 取引の事情等 取引価格（総額）_log  \
# ID
# 1117225         準工業地域    60.0   200.0  2018.75  未改装    NaN     7.431364
# 1114724  第１種中高層住居専用地域    60.0   200.0  2017.75  未改装    NaN     6.342423
# 1114753  第１種中高層住居専用地域    60.0   200.0  2016.50  改装済    NaN     6.778151
# 1120806          商業地域    80.0   400.0  2011.99  未改装    NaN     7.230449
# 1117264         準工業地域    60.0   200.0  2015.50  未改装    NaN     7.204120
#
#                 緯度          経度  建築年_en
# ID
# 1117225  42.631246  141.603122       6
# 1114724  42.631246  141.603122      13
# 1114753  42.631246  141.603122      10
# 1120806  42.631246  141.603122       7
# 1117264  42.631246  141.603122       7
#
# [5 rows x 21 columns]

# %%
df["建築年"] = df["建築年"].fillna(0)

# %%
year_list_t = set(df["建築年"].tolist())

# %%
year_list = []
for y in year_list_t:
    y = str(y).split('.')[0]
    year_list.append(y)

# %%
year_dic = {}
for i in range(76):
    if i <= 3:
        year_dic[i] = i
    elif 4 <= i <= 33:
        year_dic[i] = 4 + i//5
    elif 34 <= i <= 96:
        year_dic[i] = 10 + i//10
    
year_dic[76] = 18

# %%
df["建築年_en"] = df["建築年"].replace(year_dic).astype(int)

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error as mae
import lightgbm
import optuna.integration.lightgbm as lgb


df_train, df_val = train_test_split(df, test_size=0.2)

col = "取引価格（総額）_log"
train_y = df_train[col]
train_x = df_train.drop(col, axis=1)

val_y = df_val[col]
val_x = df_val.drop(col, axis=1)

trains = lgb.Dataset(train_x, train_y)
valids = lgb.Dataset(val_x, val_y)

# %%
opt_params = {
    "objective":"regression",
    "metric":"mae"
}

import time
start = time.time()
opt=lgb.train(
    opt_params,
    trains,
    valid_sets = valids,
    verbose_eval=200,
    num_boost_round = 1000,
    early_stopping_rounds = 100,
    time_budget = 600
)
end = time.time()
print('elaptedtime:', end-start)
# Out:
# [I 2021-05-29 03:39:27,714] A new study created in memory with name: no-name-507787e4-b955-4094-a033-a21dcfe8e632
#
#   0%|          | 0/7 [00:00<?, ?it/s]
# feature_fraction, val_score: inf:   0%|          | 0/7 [00:00<?, ?it/s]
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.036924 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12412
# [LightGBM] [Info] Number of data points in the train set: 521580, number of used features: 21
# [LightGBM] [Info] Start training from score 7.219304
# Training until validation scores don't improve for 100 rounds
# [200]	valid_0's l1: 0.0785374
# [400]	valid_0's l1: 0.0770812
# [600]	valid_0's l1: 0.0766698
# [800]	valid_0's l1: 0.0764896
# [1000]	valid_0's l1: 0.0763493
# Did not meet early stopping. Best iteration is:
# [999]	valid_0's
/it]
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.009008 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 12412
# [LightGBM] [Info] Number of data points in the train set: 521580, number of used features: 21
# [LightGBM] [Info] Start training from score 7.219304
# Training until validation scores don't improve for 100 rounds
# [200]	valid_0's l1: 0.075391
# [400]	valid_0's l1: 0.0748206
# [600]	valid_0's l1: 0.0746199
# [800]	valid_0's l1: 0.0744938
# [1000]	valid_0's l1: 0.0744217
# Did not meet early stopping. Best iteration is:
# [993]	valid_0's l1: 0.0744177
# num_leaves, val_score: 0.074406:  75%|#######5  | 15/20 [06:41<02:23, 28.75s/it]
# num_leaves, val_score: 0.074406:  80%|########  | 16/20 [06:41<01:55, 28.92s/it][I 2021-05-29 03:48:54,128] Trial 22 finished with value: 0.07441774550879611 and parameters: {'num_leaves': 107}. Best is trial 18 with value: 0.0744063558444945.
#
# num_leaves, val_score: 0.074406:  80%|########  | 16/20 [06:41<01:55, 28.92s/it]
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.009263 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 12412
# [LightGBM] [Info] Number of data points in the train set: 521580, number of used features: 21
# [LightGBM] [Info] Start training from score 7.219304
# Training until validation scores don't improve for 100 rounds
# [200]	valid_0's l1: 0.0756648
# [400]	valid_0's l1: 0.0749116
# [600]	valid_0's l1: 0.0746886
# [800]	valid_0's l1: 0.0745831
# [1000]	valid_0's l1: 0.0745153
# Did not meet early stopping. Best iteration is:
# [994]	valid_0's l1: 0.0745148
# num_leaves, val_score: 0.074406:  80%|########  | 16/20 [07:08<01:55, 28.92s/it]
# num_leaves, val_score: 0.074406:  85%|########5 | 17/20 [07:08<01:25, 28.34s/it][I 2021-05-29 03:49:21,133] Trial 23 finished with value: 0.07451476096700722 and parameters: {'num_leaves': 91}. Best is trial 18 with value: 0.0744063558444945.
#
# num_leaves, val_score: 0.074406:  85%|########5 | 17/20 [07:08<01:25, 28.34s/it]
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.008755 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 12412
# [LightGBM] [Info] Number of data points in the train set: 521580, number of used features: 21
# [LightGBM] [Info] Start training from score 7.219304
# Training until validation scores don't improve for 100 rounds
# [200]	valid_0's l1: 0.0753378
# [400]	valid_0's l1: 0.0747671
# [600]	valid_0's l1: 0.0745542
# [800]	valid_0's l1: 0.0744555
# [1000]	valid_0's l1: 0.0743988
# Did not meet early stopping. Best iteration is:
# [996]	valid_0's l1: 0.0743987
# num_leaves, val_score: 0.074399:  85%|########5 | 17/20 [07:37<01:25, 28.34s/it]
# num_leaves, val_score: 0.074399:  90%|######### | 18/20 [07:37<00:56, 28.49s/it][I 2021-05-29 03:49:49,967] Trial 24 finished with value: 0.07439874697008392 and parameters: {'num_leaves': 112}. Best is trial 24 with value: 0.07439874697008392.
# num_leaves, val_score: 0.074399:  90%|######### | 18/20 [07:37<00:50, 25.44s/it]
#
#   0%|          | 0/10 [00:00<?, ?it/s]
#
#   0%|          | 0/3 [00:00<?, ?it/s]
#
#   0%|          | 0/20 [00:00<?, ?it/s]
#
#   0%|          | 0/5 [00:00<?, ?it/s]
# elaptedtime: 622.2723155021667

# %%
# lightGBM
import lightgbm as lgb
best_params = opt.params
model = lgb.train(best_params, trains, valid_sets=valids, num_boost_round=1000, early_stopping_rounds=100, verbose_eval=200)
# Out:
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.009951 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 12412
# [LightGBM] [Info] Number of data points in the train set: 521580, number of used features: 21
# [LightGBM] [Info] Start training from score 7.219304
# Training until validation scores don't improve for 100 rounds
# [200]	valid_0's l1: 0.0753378
# [400]	valid_0's l1: 0.0747671
# [600]	valid_0's l1: 0.0745542
# [800]	valid_0's l1: 0.0744555
# [1000]	valid_0's l1: 0.0743988
# Did not meet early stopping. Best iteration is:
# [996]	valid_0's l1: 0.0743987

# %%
vals = model.predict(val_x)
mae(vals, val_y)
# Out:
# 0.07439874934497803

# %%
pd.DataFrame(model.feature_importance(), index=val_x.columns, columns=["importance"]).sort_values("importance", ascending=False)
# Out:
#            importance
# 取引時点            12816
# 地区名             11722
# 建築年             11073
# 最寄駅：名称          10173
# 面積（㎡）            9386
# 最寄駅：距離（分）        8809
# 市区町村名            7391
# 緯度               6503
# 経度               5508
# 建築年_en           4717
# 容積率（％）           4336
# 間取り              3779
# 改装               2983
# 都市計画             2868
# 都道府県名            2563
# 建ぺい率（％）          2031
# クラスタ平均           1109
# 今後の利用目的           906
# 建物の構造             842
# 用途                631
# 取引の事情等            410

# %%
df_test = pd.read_csv("/tmp/working/dataset/nishika/old_apartment_2020/test.csv", index_col=0)
df_test = data_pre(df_test)
predict = model.predict(df_test)
df_test["取引価格（総額）_log"] = predict
df_test[["取引価格（総額）_log"]].to_csv("./output/09_sub.csv")

# %%
df_test
# Out:
#          都道府県名   市区町村名   地区名 最寄駅：名称  最寄駅：距離（分）   間取り  面積（㎡）   建築年 建物の構造   用途  \
# ID
# 1000000    北海道  札幌市中央区   旭ケ丘   円山公園       26.0  ３ＬＤＫ   75.0  32.0    ＲＣ  NaN
# 1000110    北海道  札幌市中央区   大通西  西１８丁目        2.0  １ＬＤＫ   45.0  30.0   ＳＲＣ   住宅
# 1000111    北海道  札幌市中央区   大通西  西１８丁目        2.0  ２ＬＤＫ   50.0  32.0   ＳＲＣ   住宅
# 1000112    北海道  札幌市中央区   大通西  西１８丁目        3.0  ２ＬＤＫ   80.0  24.0    ＲＣ  NaN
# 1000113    北海道  札幌市中央区   大通西  西１８丁目        3.0    １Ｋ   20.0  40.0    ＲＣ  NaN
# ...        ...     ...   ...    ...        ...   ...    ...   ...   ...  ...
# 47006180   沖縄県     沖縄市    大里    NaN        NaN  ２ＬＤＫ   35.0  30.0    ＲＣ  NaN
# 47006652   沖縄県     沖縄市   比屋根    NaN        NaN  ２ＬＤＫ   60.0  37.0    ＲＣ  NaN
# 47006790   沖縄県     沖縄市    美里    NaN        NaN   ３ＤＫ   55.0  33.0    ＲＣ  NaN
# 47007026   沖縄県     沖縄市    与儀    NaN        NaN  ２ＬＤＫ   55.0   7.0    ＲＣ   住宅
# 47008203   沖縄県    うるま市  字具志川    NaN        NaN  ３ＬＤＫ   65.0  32.0    ＲＣ   住宅
#
#           ...                    都市計画 建ぺい率（％）  容積率（％）     取引時点   改装  取引の事情等  \
# ID        ...
# 1000000   ...             第１種低層住居専用地域    40.0    60.0  2020.50  未改装     NaN
# 1000110   ...                    商業地域    80.0   400.0  2020.75  未改装     NaN
# 1000111   ...                    商業地域    80.0   400.0  2020.75  改装済     NaN
# 1000112   ...                    商業地域    80.0   400.0  2020.75  改装済     NaN
# 1000113   ...                    商業地域    80.0   400.0  2020.75  未改装     NaN
# ...       ...                     ...     ...     ...      ...  ...     ...
# 47006180  ...             第１種低層住居専用地域    50.0   100.0  2020.75  NaN     NaN
# 47006652  ...  市街化区域及び市街化調整区域外の都市計画区域    70.0   200.0  2020.75  未改装     NaN
# 47006790  ...                    商業地域    80.0   400.0  2020.50  未改装     NaN
# 47007026  ...            第１種中高層住居専用地域    60.0   200.0  2020.75  改装済     NaN
# 47008203  ...  市街化区域及び市街化調整区域外の都市計画区域    60.0   200.0  2020.50  未改装  調停・競売等
#
#                  緯度          経度  クラスタ平均  建築年_en
# ID
# 1000000   43.046848  141.322114     2.0      10
# 1000110   43.046848  141.322114     2.0      10
# 1000111   43.046848  141.322114     2.0      10
# 1000112   43.046848  141.322114     2.0       8
# 1000113   43.046848  141.322114     2.0      14
# ...             ...         ...     ...     ...
# 47006180  26.334353  127.805606     3.0      10
# 47006652  26.334353  127.805606     3.0      13
# 47006790  26.334353  127.805606     3.0      10
# 47007026  26.334353  127.805606     3.0       5
# 47008203  26.378685  127.857493     3.0      10
#
# [17894 rows x 21 columns]
