# %%
from sklearn.cluster import KMeans
def data_pre2(df):
    
    df = data_pre(df)
    df_b = df.copy()
    df = df[["都道府県名", "都道府県名_en", "市区町村名", "面積（㎡）", "取引価格（総額）_log"]]
    pref_list = df["都道府県名"].tolist()
    pref_list = set(pref_list)
    df_z = pd.DataFrame()

    for pref in pref_list:
        pref_df = df[df["都道府県名"]==pref]["取引価格（総額）_log"]
        zscore_list = pref_df.tolist()
        df_t = df[df["都道府県名"]==pref]
        df_t["zscore"] = scipy.stats.zscore(zscore_list)
        df_t = df_t[["zscore"]]
        df_z = pd.concat([df_z, df_t], axis=0)

    df = pd.merge(df, df_z, on="ID")
    
    pred = KMeans(n_clusters=4).fit_predict(df[["面積（㎡）", "zscore"]])
    df["クラスタ"] = pred
    df = df[["zscore", "クラスタ"]]
    df = pd.merge(df_b, df, on="ID")
    
    return df

# %%
import pandas as pd
from input_data import input_df
import scipy.stats
import matplotlib.pyplot as plt
from pre2 import data_pre
from m01_lightgbm import train
# Out:
# <style type='text/css'>
# .datatable table.frame { margin-bottom: 0; }
# .datatable table.frame thead { border-bottom: none; }
# .datatable table.frame tr.coltypes td {  color: #FFFFFF;  line-height: 6px;  padding: 0 0.5em;}
# .datatable .bool    { background: #DDDD99; }
# .datatable .object  { background: #565656; }
# .datatable .int     { background: #5D9E5D; }
# .datatable .float   { background: #4040CC; }
# .datatable .str     { background: #CC4040; }
# .datatable .row_index {  background: var(--jp-border-color3);  border-right: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  font-size: 9px;}
# .datatable .frame tr.coltypes .row_index {  background: var(--jp-border-color0);}
# .datatable th:nth-child(2) { padding-left: 12px; }
# .datatable .hellipsis {  color: var(--jp-cell-editor-border-color);}
# .datatable .vellipsis {  background: var(--jp-layout-color0);  color: var(--jp-cell-editor-border-color);}
# .datatable .na {  color: var(--jp-cell-editor-border-color);  font-size: 80%;}
# .datatable .footer { font-size: 9px; }
# .datatable .frame_dimensions {  background: var(--jp-border-color3);  border-top: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  display: inline-block;  opacity: 0.6;  padding: 1px 10px 1px 5px;}
# </style>

# %%
df = input_df()
df = data_pre(df)
df_b = df.copy()
# Out:
# /opt/conda/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3357: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):

# %%
df = df[["都道府県名", "都道府県名_en", "市区町村名", "面積（㎡）", "取引価格（総額）_log"]]

# %%
pref_list = df["都道府県名"].tolist()
pref_list = set(pref_list)

# %%
df_z = pd.DataFrame()

for pref in pref_list:
    pref_df = df[df["都道府県名"]==pref]["取引価格（総額）_log"]
    zscore_list = pref_df.tolist()
    df_t = df[df["都道府県名"]==pref]
    df_t["zscore"] = scipy.stats.zscore(zscore_list)
    df_t = df_t[["zscore"]]
    df_z = pd.concat([df_z, df_t], axis=0)

df = pd.merge(df, df_z, on="ID")
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys

# %%
plt.scatter(df["面積（㎡）"], df["zscore"])
plt.show()

# %%
from sklearn.cluster import KMeans
pred = KMeans(n_clusters=4).fit_predict(df[["面積（㎡）", "zscore"]])

# %%
df["クラスタ"] = pred

# %%
df.head()
# Out:
#         都道府県名  都道府県名_en 市区町村名  面積（㎡）  取引価格（総額）_log    zscore  クラスタ
# ID
# 1117225   北海道         1  苫小牧市  120.0      7.431364  1.231246     3
# 1114724   北海道         1  苫小牧市   70.0      6.342423 -1.764705     0
# 1114753   北海道         1  苫小牧市   70.0      6.778151 -0.565906     0
# 1120806   北海道         1  苫小牧市  105.0      7.230449  0.678479     3
# 1117264   北海道         1  苫小牧市   90.0      7.204120  0.606041     3

# %%
df = df[["zscore", "クラスタ"]]

# %%
df = pd.merge(df_b, df, on="ID")

# %%
df.tail()
# Out:
#          都道府県名 市区町村名  地区名 最寄駅：名称  最寄駅：距離（分）   間取り  面積（㎡）   建築年 建物の構造  用途  ...  \
# ID                                                                        ...
# 47008534   沖縄県  うるま市  字宮里    NaN        NaN  ４ＬＤＫ   65.0  10.0   ＳＲＣ  住宅  ...
# 47007866   沖縄県  うるま市  字江洲    NaN        NaN  ３ＬＤＫ   70.0   6.0    ＲＣ  住宅  ...
# 47029524   沖縄県  うるま市  字塩屋    NaN        NaN  ３ＬＤＫ   75.0  22.0    ＲＣ  住宅  ...
# 47008285   沖縄県  うるま市  字塩屋    NaN        NaN  ３ＬＤＫ   75.0  22.0    ＲＣ  住宅  ...
# 47008266   沖縄県  うるま市  字塩屋    NaN        NaN  ３ＬＤＫ   75.0  22.0    ＲＣ  住宅  ...
#
#          容積率（％）     取引時点   改装  取引の事情等  取引価格（総額）_log         緯度          経度  \
# ID
# 47008534  200.0  2019.75  未改装     NaN      7.342423  26.378685  127.857493
# 47007866  200.0  2018.99  改装済     NaN      7.447158  26.378685  127.857493
# 47029524  100.0  2009.99  未改装     NaN      7.000000  26.378685  127.857493
# 47008285  100.0  2015.25  未改装     NaN      7.113943  26.378685  127.857493
# 47008266    NaN  2019.75  改装済     NaN      7.176091  26.378685  127.857493
#
#           都道府県名_en    zscore  クラスタ
# ID
# 47008534        47  0.452388     0
# 47007866        47  0.788960     0
# 47029524        47 -0.648002     3
# 47008285        47 -0.281840     3
# 47008266        47 -0.082125     3
#
# [5 rows x 23 columns]

# %%
area_list = set(df["市区町村名"].tolist())

# %%
area_class_mean = []
for area in area_list:
    area_mean = df[df["市区町村名"] == area]["クラスタ"].mean()
    area_class_mean.append(area_mean)

df_area = pd.DataFrame(area_class_mean, columns = ['クラスタ平均'])
df_area["市区町村名"] = area_list

# %%
df_area
# Out:
#        クラスタ平均    市区町村名
# 0    0.166667  南埼玉郡宮代町
# 1    1.612903  印旛郡酒々井町
# 2    0.664959      新座市
# 3    0.000000      南丹市
# 4    0.658537      郡山市
# ..        ...      ...
# 613  1.191919      三原市
# 614  0.750000   海部郡大治町
# 615  0.857143      宗像市
# 616  0.525571   大阪市平野区
# 617  0.876254      文京区
#
# [618 rows x 2 columns]

# %%
df = pd.merge(df, df_area, on="市区町村名")
df["市区町村名"] = df["市区町村名"].astype("category")

# %%
df.head()
# Out:
#   都道府県名 市区町村名   地区名 最寄駅：名称  最寄駅：距離（分）   間取り  面積（㎡）   建築年 建物の構造  用途  ...  \
# 0   北海道  苫小牧市  新中野町    苫小牧       25.0  ３ＬＤＫ  120.0  12.0    ＲＣ  住宅  ...
# 1   北海道  苫小牧市   青葉町     青葉        9.0  ３ＬＤＫ   70.0  35.0    ＲＣ  住宅  ...
# 2   北海道  苫小牧市   青葉町     青葉        3.0  ３ＬＤＫ   70.0  31.0    ＲＣ  住宅  ...
# 3   北海道  苫小牧市    表町    苫小牧        8.0  ４ＬＤＫ  105.0  18.0    ＲＣ  住宅  ...
# 4   北海道  苫小牧市  新中野町    苫小牧       25.0  ３ＬＤＫ   90.0  15.0    ＲＣ  住宅  ...
#
#       取引時点   改装  取引の事情等  取引価格（総額）_log         緯度          経度 都道府県名_en  \
# 0  2018.75  未改装     NaN      7.431364  42.631246  141.603122        1
# 1  2017.75  未改装     NaN      6.342423  42.631246  141.603122        1
# 2  2016.50  改装済     NaN      6.778151  42.631246  141.603122        1
# 3  2011.99  未改装     NaN      7.230449  42.631246  141.603122        1
# 4  2015.50  未改装     NaN      7.204120  42.631246  141.603122        1
#
#      zscore  クラスタ   クラスタ平均
# 0  1.231246     3  1.86747
# 1 -1.764705     0  1.86747
# 2 -0.565906     0  1.86747
# 3  0.678479     3  1.86747
# 4  0.606041     3  1.86747
#
# [5 rows x 24 columns]

# %%
df = df.drop(['zscore', 'クラスタ'], axis=1)

# %%
df.head()
# Out:
#   都道府県名 市区町村名   地区名 最寄駅：名称  最寄駅：距離（分）   間取り  面積（㎡）   建築年 建物の構造  用途  ...  \
# 0   北海道  苫小牧市  新中野町    苫小牧       25.0  ３ＬＤＫ  120.0  12.0    ＲＣ  住宅  ...
# 1   北海道  苫小牧市   青葉町     青葉        9.0  ３ＬＤＫ   70.0  35.0    ＲＣ  住宅  ...
# 2   北海道  苫小牧市   青葉町     青葉        3.0  ３ＬＤＫ   70.0  31.0    ＲＣ  住宅  ...
# 3   北海道  苫小牧市    表町    苫小牧        8.0  ４ＬＤＫ  105.0  18.0    ＲＣ  住宅  ...
# 4   北海道  苫小牧市  新中野町    苫小牧       25.0  ３ＬＤＫ   90.0  15.0    ＲＣ  住宅  ...
#
#   建ぺい率（％） 容積率（％）     取引時点   改装  取引の事情等 取引価格（総額）_log         緯度          経度  \
# 0    60.0  200.0  2018.75  未改装     NaN     7.431364  42.631246  141.603122
# 1    60.0  200.0  2017.75  未改装     NaN     6.342423  42.631246  141.603122
# 2    60.0  200.0  2016.50  改装済     NaN     6.778151  42.631246  141.603122
# 3    80.0  400.0  2011.99  未改装     NaN     7.230449  42.631246  141.603122
# 4    60.0  200.0  2015.50  未改装     NaN     7.204120  42.631246  141.603122
#
#    都道府県名_en   クラスタ平均
# 0         1  1.86747
# 1         1  1.86747
# 2         1  1.86747
# 3         1  1.86747
# 4         1  1.86747
#
# [5 rows x 22 columns]

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error as mae
import lightgbm
import optuna.integration.lightgbm as lgb


df_train, df_val = train_test_split(df, test_size=0.2)

col = "取引価格（総額）_log"
train_y = df_train[col]
train_x = df_train.drop(col, axis=1)

val_y = df_val[col]
val_x = df_val.drop(col, axis=1)

trains = lgb.Dataset(train_x, train_y)
valids = lgb.Dataset(val_x, val_y)

# %%
opt_params = {
    "objective":"regression",
    "metric":"mae"
}


opt=lgb.train(
    opt_params,
    trains,
    valid_sets = valids,
    verbose_eval=200,
    num_boost_round = 1000,
    early_stopping_rounds = 100
)
# Out:
# [I 2021-05-27 12:50:13,163] A new study created in memory with name: no-name-2603dd05-3316-426c-b43f-bd7368acd7d5
# feature_fraction, val_score: inf:   0%|          | 0/7 [00:00<?, ?it/s]
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.034582 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12637
# [LightGBM] [Info] Number of data points in the train set: 521580, number of used features: 21
# [LightGBM] [Info] Start training from score 7.219625
# Training until validation scores don't improve for 100 rounds
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1433: UserWarning: Overriding the parameters from Reference Dataset.
#   _log_warning('Overriding the parameters from Reference Dataset.')
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1245: UserWarning: categorical_column in param dict is overridden.
#   _log_warning('{} in param dict is overridden.'.format(cat_alias))
# [200]	valid_0's l1: 0.0782993
# [400]	valid_0's l1: 0.0766239
# [600]	valid_0's l1: 0.0761056
# [800]	valid_0's l1: 0.0758494
# [1000]	valid_0's l1: 0.0756392
# Did not meet early stopping. Best iteration is:
# [1000]	valid_0's l1: 0.0756392
# feature_fraction, val_score: 0.075639:  14%|#4        | 1/7 [00:22<02:15, 22.60s/it][I 2021-05-27 12:50:35,770] Trial 0 finished with value: 0.07563918558891704 and parameters: {'feature_fraction': 0.6}. Best is trial 0 with value: 0.07563918558891704.
# feature_fraction, val_score: 0.075639:  14%|#4        | 1/7 [00:22<02:15, 22.60s/it]
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.011285 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 12637
# [LightGBM] [Info] Number of data points in the train set: 521580, number of used features: 21
# [LightGBM] [Info] Start training from score 7.219625
# Training until validation scores don't improve for 100 rounds
# [200]	valid_0's l1: 0.0783543
# [400]	valid_0's l1: 0.0765576
# [600]	valid_0's l1: 0.076034
# [800]	valid_0's l1: 0.075745
# [1000]	valid_0's l1: 0.07557
# Did not meet early stopping. Best iteration is:
# [991]	valid_0's l1: 0.0755695
# feature_fraction, val_score: 0.075570:  29%|##8       | 2/7 [00:47<01:59, 23.92s/it][I 2021-05-27 12:51:00,622] Trial 1 finished with value: 0.0755695064634154 and parameters: {'feature_fraction': 0.5}. Best is trial 1 with value: 0.0755695064634154.
# feature_fraction, val_score: 0.075570:  29%|##8       | 2/7 [00:47<01:59, 23.92s/it]
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.035038 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12637
# [LightGBM] [Info] Number of data points in the train set: 521580, number of used features: 21
# [LightGBM] [Info] Start training from score 7.219625
# Training until validation scores don't improve for 100 rounds
# [200]	valid_0's l1: 0.0784053
# [400]	valid_0's l1: 0.0768047
# [600]	valid_0's l1: 0.0763956
# [800]	valid_0's l1: 0.0762142
# [1000]	valid_0's l1: 0.0760316
# Did not meet early stopping. Best iteration is:
# [978]	valid_0's l1: 0.0760213
# feature_fraction, val_score: 0.075570:  43%|####2     | 3/7 [01:12<01:37, 24.31s/it][I 2021-05-27 12:51:25,383] Trial 2 finished with value: 0.07602126046579859 and parameters: {'feature_fraction': 0.8}. Best is trial 1 with value: 0.0755695064634154.
# feature_fraction, val_score: 0.075570:  43%|####2     | 3/7 [01:12<01:37, 24.31s/it]
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.035249 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12637
# [LightGBM] [Info] Number of data points in the train set: 521580, number of used features: 21
# [LightGBM] [Info] Start training from score 7.219625
# Training until validation scores don't improve for 100 rounds
# [200]	valid_0's l1: 0.078389
# [400]	valid_0's l1: 0.0768131
# [600]	valid_0's l1: 0.0762985
# [800]	valid_0's l1: 0.0761601
# [1000]	valid_0's l1: 0.07596
# Did not meet early stopping. Best iteration is:
# [995]	valid_0's l1: 0.0759585
# feature_fraction, val_score: 0.075570:  57%|#####7    | 4/7 [01:35<01:11, 23.76s/it][I 2021-05-27 12:51:48,316] Trial 3 finished with value: 0.07595854387883692 and parameters: {'feature_fraction': 0.7}. Best is trial 1 with value: 0.0755695064634154.
# feature_fraction, val_score: 0.075570:  57%|#####7    | 4/7 [01:35<01:11, 23.76s/it]
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.016215 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 12637
# [LightGBM] [Info] Number of data points in the train set: 521580, number of used features: 21
# [LightGBM] [Info] Start training from score 7.219625
# Training until validation scores don't improve for 100 rounds
# [200]	valid_0's l1: 0.0785656
# [400]	valid_0's l1: 0.0770428
# [600]	valid_0's l1: 0.0766656
# [800]	valid_0's l1: 0.0764899
# [1000]	valid_0's l1: 0.0763626
# Did not meet early stopping. Best iteration is:
# [1000]	valid_0's l1: 0.0763626
# feature_fraction, val_score: 0.075570:  71%|#######1  | 5/7 [02:02<00:50, 25.02s/it][I 2021-05-27 12:52:15,551] Trial 4 finished with value: 0.07636261228367093 and parameters: {'feature_fraction': 1.0}. Best is trial 1 with value: 0.0755695064634154.
# feature_fraction, val_score: 0.075570:  71%|#######1  | 5/7 [02:02<00:50, 25.02s/it]
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.008977 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 12637
# [LightGBM] [Info] Number of data points in the train set: 521580, number of used features: 21
# [LightGBM] [Info] Start training from score 7.219625
# Training until validation scores don't improve for 100 rounds
# [200]	valid_0's l1: 0.0785232
# [400]	valid_0's l1: 0.0764504
# [600]	valid_0's l1: 0.0758874
# [800]	valid_0's l1: 0.0756344
# [1000]	valid_0's l1: 0.075447
# Did not meet early stopping. Best iteration is:
# [1000]	valid_0's l1: 0.075447
# feature_fraction, val_score: 0.075447:  86%|########5 | 6/7 [02:22<00:23, 23.45s/it][I 2021-05-27 12:52:35,953] Trial 5 finished with value: 0.07544703153316662 and parameters: {'feature_fraction': 0.4}. Best is trial 5 with value: 0.07544703153316662.
# feature_fraction, val_score: 0.075447:  86%|########5 | 6/7 [02:22<00:23, 23.45s/it]
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.058408 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12637
# [LightGBM] [Info] Number of data points in the train set: 521580, number of used features: 21
# [LightGBM] [Info] Start training from score 7.219625
# Training until validation scores don't improve for 100 rounds
# [200]	valid_0's l1: 0.0785575
# [400]	valid_0's l1: 0.0769315
# [600]	valid_0's l1: 0.0765312
# [800]	valid_0's l1: 0.0763401
# [1000]	valid_0's l1: 0.0762009
# Did not meet early stopping. Best iteration is:
# [1000]	valid_0's l1: 0.0762009
# feature_fraction, val_score: 0.075447: 100%|##########| 7/7 [02:49<00:00, 24.39s/it][I 2021-05-27 12:53:02,300] Trial 6 finished with value: 0.07620085468954643 and parameters: {'feature_fraction': 0.8999999999999999}. Best is trial 5 with value: 0.07544703153316662.
# feature_fraction, val_score: 0.075447: 100%|##########| 7/7 [02:49<00:00, 24.16s/it]
# num_leaves, val_score: 0.075447:   0%|          | 0/20 [00:00<?, ?it/s]
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.009268 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 12637
# [LightGBM] [Info] Number of data points in the train set: 521580, number of used features: 21
# [LightGBM] [Info] Start training from score 7.219625
# Training until validation scores don't improve for 100 rounds
# [200]	valid_0's l1: 0.0764197
# [400]	valid_0's l1: 0.0752688
# [600]	valid_0's l1: 0.0749797
# [800]	valid_0's l1: 0.0748327
# [1000]	valid_0's l1: 0.0747146
# Did not meet early stopping. Best iteration is:
# [1000]	valid_0's l1: 0.0747146
# num_leaves, val_score: 0.074715:   5%|5         | 1/20 [00:24<07:41, 24.31s/it][I 2021-05-27 12:53:26,615] Trial 7 finished with value: 0.07471459315880648 and parameters: {'num_leaves': 62}. Best is trial 7 with value: 0.07471459315880648.
# num_leaves, val_score: 0.074715:   5%|5         | 1/20 [00:24<07:41, 24.31s/it]
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.009378 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 12637
# [LightGBM] [Info] Number of data points in the train set: 521580, number of used features: 21
# [LightGBM] [Info] Start training from score 7.219625
# Training until validation scores don't improve for 100 rounds
# [200]	valid_0's l1: 0.0751793
# [400]	valid_0's l1: 0.074684
# [600]	valid_0's l1: 0.0746103
# [800]	valid_0's l1: 0.0745764
# [1000]	valid_0's l1: 0.0745477
# Did not meet early stopping. Best iteration is:
# [958]	valid_0's l1: 0.0745444
# num_leaves, val_score: 0.074544:  10%|#         | 2/20 [00:57<08:49, 29.43s/it][I 2021-05-27 12:53:59,635] Trial 8 finished with value: 0.07454435205677824 and parameters: {'num_leaves': 152}. Best is trial 8 with value: 0.07454435205677824.
# num_leaves, val_score: 0.074544:  10%|#         | 2/20 [00:57<08:49, 29.43s/it]
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.009031 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 12637
# [LightGBM] [Info] Number of data points in the train set: 521580, number of used features: 21
# [LightGBM] [Info] Start training from score 7.219625
# Training until validation scores don't improve for 100 rounds
# [200]	valid_0's l1: 0.0758247
# [400]	valid_0's l1: 0.0749265
# [600]	valid_0's l1: 0.074705
# [800]	valid_0's l1: 0.074566
# [1000]	valid_0's l1: 0.0745216
# Did not meet early stopping. Best iteration is:
# [997]	valid_0's l1: 0.07452
# num_leaves, val_score: 0.074520:  15%|#5        | 3/20 [01:24<08:00, 28.28s/it][I 2021-05-27 12:54:26,547] Trial 9 finished with value: 0.07451998740285824 and parameters: {'num_leaves': 84}. Best is trial 9 with value: 0.07451998740285824.
# num_leaves, val_score: 0.074520:  15%|#5        | 3/20 [01:24<08:00, 28.28s/it]
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.009529 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 12637
# [LightGBM] [Info] Number of data points in the train set: 521580, number of used features: 21
# [LightGBM] [Info] Start training from score 7.219625
# Training until validation scores don't improve for 100 rounds
# [200]	valid_0's l1: 0.0751537
# [400]	valid_0's l1: 0.0746345
# [600]	valid_0's l1: 0.074513
# [800]	valid_0's l1: 0.0744829
# [1000]	valid_0's l1: 0.074457
# Did not meet early stopping. Best iteration is:
# [993]	valid_0's l1: 0.0744521
# num_leaves, val_score: 0.074452:  20%|##        | 4/20 [01:57<08:05, 30.37s/it][I 2021-05-27 12:55:00,121] Trial 10 finished with value: 0.07445205912370095 and parameters: {'num_leaves': 141}. Best is trial 10 with value: 0.07445205912370095.
# num_leaves, val_score: 0.074452:  20%|##        | 4/20 [01:57<08:05, 30.37s/it]
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.009522 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 12637
# [LightGBM] [Info] Number of data points in the train set: 521580, number of used features: 21
# [LightGBM] [Info] Start training from score 7.219625
# Training until validation scores don't improve for 100 rounds
# [200]	valid_0's l1: 0.0752332
# [400]	valid_0's l1: 0.0747072
# [600]	valid_0's l1: 0.0745827
# [800]	valid_0's l1: 0.074541
# [1000]	valid_0's l1: 0.0745157
# Did not meet early stopping. Best iteration is:
# [1000]	valid_0's l1: 0.0745157
# num_leaves, val_score: 0.074452:  25%|##5       | 5/20 [02:30<07:48, 31.22s/it][I 2021-05-27 12:55:32,847] Trial 11 finished with value: 0.07451568736405008 and parameters: {'num_leaves': 140}. Best is trial 10 with value: 0.07445205912370095.
# num_leaves, val_score: 0.074452:  25%|##5       | 5/20 [02:30<07:48, 31.22s/it]
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.009303 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 12637
# [LightGBM] [Info] Number of data points in the train set: 521580, number of used features: 21
# [LightGBM] [Info] Start training from score 7.219625
# Training until validation scores don't improve for 100 rounds
# [200]	valid_0's l1: 0.07496
# [400]	valid_0's l1: 0.0746583
# [600]	valid_0's l1: 0.0745827
# Early stopping, best iteration is:
# [661]	valid_0's l1: 0.0745497
# num_leaves, val_score: 0.074452:  30%|###       | 6/20 [03:02<07:19, 31.41s/it][I 2021-05-27 12:56:04,625] Trial 12 finished with value: 0.07454966867072686 and parameters: {'num_leaves': 202}. Best is trial 10 with value: 0.07445205912370095.
# num_leaves, val_score: 0.074452:  30%|###       | 6/20 [03:02<07:19, 31.41s/it]
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.008549 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 12637
# [LightGBM] [Info] Number of data points in the train set: 521580, number of used features: 21
# [LightGBM] [Info] Start training from score 7.219625
# Training until validation scores don't improve for 100 rounds
# [200]	valid_0's l1: 0.0748721
# [400]	valid_0's l1: 0.0746351
# Early stopping, best iteration is:
# [396]	valid_0's l1: 0.0746309
# num_leaves, val_score: 0.074452:  35%|###5      | 7/20 [03:29<06:31, 30.14s/it][I 2021-05-27 12:56:32,147] Trial 13 finished with value: 0.07463087854809498 and parameters: {'num_leaves': 238}. Best is trial 10 with value: 0.07445205912370095.
# num_leaves, val_score: 0.074452:  35%|###5      | 7/20 [03:29<06:31, 30.14s/it]
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.008570 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 12637
# [LightGBM] [Info] Number of data points in the train set: 521580, number of used features: 21
# [LightGBM] [Info] Start training from score 7.219625
# Training until validation scores don't improve for 100 rounds
# [200]	valid_0's l1: 0.0751895
# [400]	valid_0's l1: 0.0746444
# [600]	valid_0's l1: 0.0745482
# Early stopping, best iteration is:
# [669]	valid_0's l1: 0.0745124
# num_leaves, val_score: 0.074452:  40%|####      | 8/20 [03:58<05:55, 29.67s/it][I 2021-05-27 12:57:00,802] Trial 14 finished with value: 0.07451241927233786 and parameters: {'num_leaves': 137}. Best is trial 10 with value: 0.07445205912370095.
# num_leaves, val_score: 0.074452:  40%|####      | 8/20 [03:58<05:55, 29.67s/it]
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.008786 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 12637
# [LightGBM] [Info] Number of data points in the train set: 521580, number of used features: 21
# [LightGBM] [Info] Start training from score 7.219625
# Training until validation scores don't improve for 100 rounds
# [200]	valid_0's l1: 0.0752048
# [400]	valid_0's l1: 0.0747249
# [600]	valid_0's l1: 0.0745642
# [800]	valid_0's l1: 0.074495
# Early stopping, best iteration is:
# [879]	valid_0's l1: 0.0744848
# num_leaves, val_score: 0.074452:  45%|####5     | 9/20 [04:30<05:35, 30.50s/it][I 2021-05-27 12:57:33,149] Trial 15 finished with value: 0.0744847694321062 and parameters: {'num_leaves': 134}. Best is trial 10 with value: 0.07445205912370095.
# num_leaves, val_score: 0.074452:  45%|####5     | 9/20 [04:30<05:35, 30.50s/it]
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.009338 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 12637
# [LightGBM] [Info] Number of data points in the train set: 521580, number of used features: 21
# [LightGBM] [Info] Start training from score 7.219625
# Training until validation scores don't improve for 100 rounds
# [200]	valid_0's l1: 0.0750197
# [400]	valid_0's l1: 0.0746837
# [600]	valid_0's l1: 0.0745859
# Early stopping, best iteration is:
# [696]	valid_0's l1: 0.0745547
# num_leaves, val_score: 0.074452:  50%|#####     | 10/20 [05:04<05:14, 31.40s/it][I 2021-05-27 12:58:06,564] Trial 16 finished with value: 0.07455474680309579 and parameters: {'num_leaves': 183}. Best is trial 10 with value: 0.07445205912370095.
# num_leaves, val_score: 0.074452:  50%|#####     | 10/20 [05:04<05:14, 31.40s/it]
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.008681 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 12637
# [LightGBM] [Info] Number of data points in the train set: 521580, number of used features: 21
# [LightGBM] [Info] Start training from score 7.219625
# Training until validation scores don't improve for 100 rounds
# [200]	valid_0's l1: 0.0785704
# [400]	valid_0's l1: 0.0765102
# [600]	valid_0's l1: 0.0759419
# [800]	valid_0's l1: 0.0756796
# [1000]	valid_0's l1: 0.0754635
# Did not meet early stopping. Best iteration is:
# [1000]	valid_0's l1: 0.0754635
# num_leaves, val_score: 0.074452:  55%|#####5    | 11/20 [05:24<04:12, 28.05s/it][I 2021-05-27 12:58:27,000] Trial 17 finished with value: 0.07546347858765169 and parameters: {'num_leaves': 30}. Best is trial 10 with value: 0.07445205912370095.
# num_leaves, val_score: 0.074452:  55%|#####5    | 11/20 [05:24<04:12, 28.05s/it]
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.008982 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 12637
# [LightGBM] [Info] Number of data points in the train set: 521580, number of used features: 21
# [LightGBM] [Info] Start training from score 7.219625
# Training until validation scores don't improve for 100 rounds
# [200]	valid_0's l1: 0.0755857
# [400]	valid_0's l1: 0.0748638
# [600]	valid_0's l1: 0.074689
# [800]	valid_0's l1: 0.0745782
# [1000]	valid_0's l1: 0.074518
# Did not meet early stopping. Best iteration is:
# [1000]	valid_0's l1: 0.074518
# num_leaves, val_score: 0.074452:  60%|######    | 12/20 [05:53<03:45, 28.15s/it][I 2021-05-27 12:58:55,395] Trial 18 finished with value: 0.07451803064601961 and parameters: {'num_leaves': 96}. Best is trial 10 with value: 0.07445205912370095.
# num_leaves, val_score: 0.074452:  60%|######    | 12/20 [05:53<03:45, 28.15s/it]
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.010899 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 12637
# [LightGBM] [Info] Number of data points in the train set: 521580, number of used features: 21
# [LightGBM] [Info] Start training from score 7.219625
# Training until validation scores don't improve for 100 rounds
# [200]	valid_0's l1: 0.0749463
# [400]	valid_0's l1: 0.0746424
# [600]	valid_0's l1: 0.0746011
# Early stopping, best iteration is:
# [697]	valid_0's l1: 0.0745803
# num_leaves, val_score: 0.074452:  65%|######5   | 13/20 [06:26<03:27, 29.63s/it][I 2021-05-27 12:59:28,422] Trial 19 finished with value: 0.07458031792828256 and parameters: {'num_leaves': 184}. Best is trial 10 with value: 0.07445205912370095.
# num_leaves, val_score: 0.074452:  65%|######5   | 13/20 [06:26<03:27, 29.63s/it]
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.009331 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 12637
# [LightGBM] [Info] Number of data points in the train set: 521580, number of used features: 21
# [LightGBM] [Info] Start training from score 7.219625
# Training until validation scores don't improve for 100 rounds
# [200]	valid_0's l1: 0.0753535
# [400]	valid_0's l1: 0.0746658
# [600]	valid_0's l1: 0.0745004
# [800]	valid_0's l1: 0.0744207
# [1000]	valid_0's l1: 0.0743875
# Did not meet early stopping. Best iteration is:
# [968]	valid_0's l1: 0.0743862
# num_leaves, val_score: 0.074386:  70%|#######   | 14/20 [06:57<03:01, 30.22s/it][I 2021-05-27 13:00:00,014] Trial 20 finished with value: 0.07438619277223318 and parameters: {'num_leaves': 113}. Best is trial 20 with value: 0.07438619277223318.
# num_leaves, val_score: 0.074386:  70%|#######   | 14/20 [06:57<03:01, 30.22s/it]
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.009230 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 12637
# [LightGBM] [Info] Number of data points in the train set: 521580, number of used features: 21
# [LightGBM] [Info] Start training from score 7.219625
# Training until validation scores don't improve for 100 rounds
# [200]	valid_0's l1: 0.0755317
# [400]	valid_0's l1: 0.074842
# [600]	valid_0's l1: 0.0746338
# [800]	valid_0's l1: 0.0745478
# [1000]	valid_0's l1: 0.0745164
# Did not meet early stopping. Best iteration is:
# [978]	valid_0's l1: 0.0745134
# num_leaves, val_score: 0.074386:  75%|#######5  | 15/20 [07:26<02:29, 29.93s/it][I 2021-05-27 13:00:29,274] Trial 21 finished with value: 0.07451342063845678 and parameters: {'num_leaves': 100}. Best is trial 20 with value: 0.07438619277223318.
# num_leaves, val_score: 0.074386:  75%|#######5  | 15/20 [07:26<02:29, 29.93s/it]
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.009513 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 12637
# [LightGBM] [Info] Number of data points in the train set: 521580, number of used features: 21
# [LightGBM] [Info] Start training from score 7.219625
# Training until validation scores don't improve for 100 rounds
# [200]	valid_0's l1: 0.0792607
# [400]	valid_0's l1: 0.0768013
# [600]	valid_0's l1: 0.0761544
# [800]	valid_0's l1: 0.0758463
# [1000]	valid_0's l1: 0.075656
# Did not meet early stopping. Best iteration is:
# [1000]	valid_0's l1: 0.075656
# num_leaves, val_score: 0.074386:  80%|########  | 16/20 [07:47<01:48, 27.11s/it][I 2021-05-27 13:00:49,814] Trial 22 finished with value: 0.07565601990521666 and parameters: {'num_leaves': 26}. Best is trial 20 with value: 0.07438619277223318.
# num_leaves, val_score: 0.074386:  80%|########  | 16/20 [07:47<01:48, 27.11s/it]
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.009312 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 12637
# [LightGBM] [Info] Number of data points in the train set: 521580, number of used features: 21
# [LightGBM] [Info] Start training from score 7.219625
# Training until validation scores don't improve for 100 rounds
# [200]	valid_0's l1: 0.0764257
# [400]	valid_0's l1: 0.0752378
# [600]	valid_0's l1: 0.0749188
# [800]	valid_0's l1: 0.0747578
# [1000]	valid_0's l1: 0.0746481
# Did not meet early stopping. Best iteration is:
# [1000]	valid_0's l1: 0.0746481
# num_leaves, val_score: 0.074386:  85%|########5 | 17/20 [08:12<01:19, 26.41s/it][I 2021-05-27 13:01:14,601] Trial 23 finished with value: 0.07464809752560482 and parameters: {'num_leaves': 57}. Best is trial 20 with value: 0.07438619277223318.
# num_leaves, val_score: 0.074386:  85%|########5 | 17/20 [08:12<01:19, 26.41s/it]
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.009261 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 12637
# [LightGBM] [Info] Number of data points in the train set: 521580, number of used features: 21
# [LightGBM] [Info] Start training from score 7.219625
# Training until validation scores don't improve for 100 rounds
# [200]	valid_0's l1: 0.0750842
# [400]	valid_0's l1: 0.0747131
# [600]	valid_0's l1: 0.0745799
# Early stopping, best iteration is:
# [672]	valid_0's l1: 0.0745634
# num_leaves, val_score: 0.074386:  90%|######### | 18/20 [08:43<00:55, 27.94s/it][I 2021-05-27 13:01:46,106] Trial 24 finished with value: 0.0745633607196721 and parameters: {'num_leaves': 167}. Best is trial 20 with value: 0.07438619277223318.
# num_leaves, val_score: 0.074386:  90%|######### | 18/20 [08:43<00:55, 27.94s/it]
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.009276 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 12637
# [LightGBM] [Info] Number of data points in the train set: 521580, number of used features: 21
# [LightGBM] [Info] Start training from score 7.219625
# Training until validation scores don't improve for 100 rounds
# [200]	valid_0's l1: 0.074963
# [400]	valid_0's l1: 0.0746991
# [600]	valid_0's l1: 0.0746772
# Early stopping, best iteration is:
# [657]	valid_0's l1: 0.0746703
# num_leaves, val_score: 0.074386:  95%|#########5| 19/20 [09:19<00:30, 30.35s/it][I 2021-05-27 13:02:22,087] Trial 25 finished with value: 0.07467026175318545 and parameters: {'num_leaves': 229}. Best is trial 20 with value: 0.07438619277223318.
# num_leaves, val_score: 0.074386:  95%|#########5| 19/20 [09:19<00:30, 30.35s/it]
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.009492 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 12637
# [LightGBM] [Info] Number of data points in the train set: 521580, number of used features: 21
# [LightGBM] [Info] Start training from score 7.219625
# Training until validation scores don't improve for 100 rounds
# [200]	valid_0's l1: 0.0754614
# [400]	valid_0's l1: 0.0747786
# [600]	valid_0's l1: 0.0745979
# [800]	valid_0's l1: 0.0744902
# [1000]	valid_0's l1: 0.0744448
# Did not meet early stopping. Best iteration is:
# [978]	valid_0's l1: 0.0744416
# num_leaves, val_score: 0.074386: 100%|##########| 20/20 [09:48<00:00, 29.99s/it][I 2021-05-27 13:02:51,215] Trial 26 finished with value: 0.07444155622126816 and parameters: {'num_leaves': 107}. Best is trial 20 with value: 0.07438619277223318.
# num_leaves, val_score: 0.074386: 100%|##########| 20/20 [09:48<00:00, 29.45s/it]
# bagging, val_score: 0.074386:   0%|          | 0/10 [00:00<?, ?it/s]
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.009250 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 12637
# [LightGBM] [Info] Number of data points in the train set: 521580, number of used features: 21
# [LightGBM] [Info] Start training from score 7.219625
# Training until validation scores don't improve for 100 rounds
# [200]	valid_0's l1: 0.0756837
# [400]	valid_0's l1: 0.074991
# [600]	valid_0's l1: 0.0747881
# [800]	valid_0's l1: 0.0747133
# Early stopping, best iteration is:
# [885]	valid_0's l1: 0.0746968
# bagging, val_score: 0.074386:  10%|#         | 1/10 [01:26<12:55, 86.12s/it][I 2021-05-27 13:04:17,349] Trial 27 finished with value: 0.07469680429324568 and parameters: {'bagging_fraction': 0.8806106484689442, 'bagging_freq': 4}. Best is trial 27 with value: 0.07469680429324568.
# bagging, val_score: 0.074386:  10%|#         | 1/10 [01:26<12:55, 86.12s/it]
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.008723 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 12637
# [LightGBM] [Info] Number of data points in the train set: 521580, number of used features: 21
# [LightGBM] [Info] Start training from score 7.219625
# Training until validation scores don't improve for 100 rounds
# [200]	valid_0's l1: 0.0758241
# [400]	valid_0's l1: 0.0752117
# [600]	valid_0's l1: 0.0750037
# [800]	valid_0's l1: 0.0749235
# Early stopping, best iteration is:
# [863]	valid_0's l1: 0.074902
# bagging, val_score: 0.074386:  20%|##        | 2/10 [02:32<09:56, 74.59s/it][I 2021-05-27 13:05:23,860] Trial 28 finished with value: 0.0749020157531428 and parameters: {'bagging_fraction': 0.7891104694817781, 'bagging_freq': 1}. Best is trial 27 with value: 0.07469680429324568.
# bagging, val_score: 0.074386:  20%|##        | 2/10 [02:32<09:56, 74.59s/it]
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.008897 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 12637
# [LightGBM] [Info] Number of data points in the train set: 521580, number of used features: 21
# [LightGBM] [Info] Start training from score 7.219625
# Training until validation scores don't improve for 100 rounds
# [200]	valid_0's l1: 0.07554
# [400]	valid_0's l1: 0.0749003
# [600]	valid_0's l1: 0.0747036
# [800]	valid_0's l1: 0.0746321
# Early stopping, best iteration is:
# [848]	valid_0's l1: 0.0746206
# bagging, val_score: 0.074386:  30%|###       | 3/10 [03:41<08:23, 71.94s/it][I 2021-05-27 13:06:32,660] Trial 29 finished with value: 0.07462061662237836 and parameters: {'bagging_fraction': 0.9432715207483967, 'bagging_freq': 5}. Best is trial 29 with value: 0.07462061662237836.
# bagging, val_score: 0.074386:  30%|###       | 3/10 [03:41<08:23, 71.94s/it]
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.009557 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 12637
# [LightGBM] [Info] Number of data points in the train set: 521580, number of used features: 21
# [LightGBM] [Info] Start training from score 7.219625
# Training until validation scores don't improve for 100 rounds
# [200]	valid_0's l1: 0.0771893
# [400]	valid_0's l1: 0.0766589
# [600]	valid_0's l1: 0.0763967
# Early stopping, best iteration is:
# [669]	valid_0's l1: 0.076353
# bagging, val_score: 0.074386:  40%|####      | 4/10 [04:53<07:12, 72.00s/it][I 2021-05-27 13:07:44,755] Trial 30 finished with value: 0.0763529993423938 and parameters: {'bagging_fraction': 0.41144637077881574, 'bagging_freq': 4}. Best is trial 29 with value: 0.07462061662237836.
# bagging, val_score: 0.074386:  40%|####      | 4/10 [04:53<07:12, 72.00s/it]
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.010275 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 12637
# [LightGBM] [Info] Number of data points in the train set: 521580, number of used features: 21
# [LightGBM] [Info] Start training from score 7.219625
# Training until validation scores don't improve for 100 rounds
# [200]	valid_0's l1: 0.0756865
# [400]	valid_0's l1: 0.0750279
# [600]	valid_0's l1: 0.0748305
# [800]	valid_0's l1: 0.0747874
# [1000]	valid_0's l1: 0.0747668
# Did not meet early stopping. Best iteration is:
# [951]	valid_0's l1: 0.0747583
# bagging, val_score: 0.074386:  50%|#####     | 5/10 [06:21<06:28, 77.62s/it][I 2021-05-27 13:09:12,321] Trial 31 finished with value: 0.07475830475403973 and parameters: {'bagging_fraction': 0.8928160275957376, 'bagging_freq': 4}. Best is trial 29 with value: 0.07462061662237836.
# bagging, val_score: 0.074386:  50%|#####     | 5/10 [06:21<06:28, 77.62s/it]
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.009866 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 12637
# [LightGBM] [Info] Number of data points in the train set: 521580, number of used features: 21
# [LightGBM] [Info] Start training from score 7.219625
# Training until validation scores don't improve for 100 rounds
# [200]	valid_0's l1: 0.07553
# [400]	valid_0's l1: 0.0748714
# [600]	valid_0's l1: 0.0746496
# [800]	valid_0's l1: 0.0745906
# [1000]	valid_0's l1: 0.0745707
# Did not meet early stopping. Best iteration is:
# [987]	valid_0's l1: 0.0745598
# bagging, val_score: 0.074386:  60%|######    | 6/10 [07:35<05:06, 76.62s/it][I 2021-05-27 13:10:26,997] Trial 32 finished with value: 0.07455975567863685 and parameters: {'bagging_fraction': 0.9385711107673237, 'bagging_freq': 6}. Best is trial 32 with value: 0.07455975567863685.
# bagging, val_score: 0.074386:  60%|######    | 6/10 [07:35<05:06, 76.62s/it]
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.009514 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 12637
# [LightGBM] [Info] Number of data points in the train set: 521580, number of used features: 21
# [LightGBM] [Info] Start training from score 7.219625
# Training until validation scores don't improve for 100 rounds
# [200]	valid_0's l1: 0.0755097
# [400]	valid_0's l1: 0.0748789
# [600]	valid_0's l1: 0.074653
# [800]	valid_0's l1: 0.0745962
# [1000]	valid_0's l1: 0.0745537
# Did not meet early stopping. Best iteration is:
# [964]	valid_0's l1: 0.0745455
# bagging, val_score: 0.074386:  70%|#######   | 7/10 [08:40<03:38, 72.88s/it][I 2021-05-27 13:11:32,176] Trial 33 finished with value: 0.0745454647646764 and parameters: {'bagging_fraction': 0.9573890667747372, 'bagging_freq': 6}. Best is trial 33 with value: 0.0745454647646764.
# bagging, val_score: 0.074386:  70%|#######   | 7/10 [08:40<03:38, 72.88s/it]
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.009157 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 12637
# [LightGBM] [Info] Number of data points in the train set: 521580, number of used features: 21
# [LightGBM] [Info] Start training from score 7.219625
# Training until validation scores don't improve for 100 rounds
# [200]	valid_0's l1: 0.0754775
# [400]	valid_0's l1: 0.07487
# [600]	valid_0's l1: 0.0746755
# [800]	valid_0's l1: 0.0746167
# Early stopping, best iteration is:
# [857]	valid_0's l1: 0.0745949
# bagging, val_score: 0.074386:  80%|########  | 8/10 [09:54<02:26, 73.13s/it][I 2021-05-27 13:12:45,836] Trial 34 finished with value: 0.07459486353819776 and parameters: {'bagging_fraction': 0.930117395233934, 'bagging_freq': 5}. Best is trial 33 with value: 0.0745454647646764.
# bagging, val_score: 0.074386:  80%|########  | 8/10 [09:54<02:26, 73.13s/it]
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.009098 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 12637
# [LightGBM] [Info] Number of data points in the train set: 521580, number of used features: 21
# [LightGBM] [Info] Start training from score 7.219625
# Training until validation scores don't improve for 100 rounds
# [200]	valid_0's l1: 0.0756415
# [400]	valid_0's l1: 0.0749529
# [600]	valid_0's l1: 0.0747532
# [800]	valid_0's l1: 0.074652
# [1000]	valid_0's l1: 0.0746153
# Did not meet early stopping. Best iteration is:
# [986]	valid_0's l1: 0.0746109
# bagging, val_score: 0.074386:  90%|######### | 9/10 [10:51<01:08, 68.16s/it][I 2021-05-27 13:13:43,087] Trial 35 finished with value: 0.07461086689701944 and parameters: {'bagging_fraction': 0.8888398899644943, 'bagging_freq': 1}. Best is trial 33 with value: 0.0745454647646764.
# bagging, val_score: 0.074386:  90%|######### | 9/10 [10:51<01:08, 68.16s/it]
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.009220 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 12637
# [LightGBM] [Info] Number of data points in the train set: 521580, number of used features: 21
# [LightGBM] [Info] Start training from score 7.219625
# Training until validation scores don't improve for 100 rounds
# [200]	valid_0's l1: 0.0755788
# [400]	valid_0's l1: 0.0749829
# [600]	valid_0's l1: 0.07482
# [800]	valid_0's l1: 0.0747568
# [1000]	valid_0's l1: 0.0747115
# Did not meet early stopping. Best iteration is:
# [982]	valid_0's l1: 0.0747046
# bagging, val_score: 0.074386: 100%|##########| 10/10 [11:59<00:00, 68.13s/it][I 2021-05-27 13:14:51,149] Trial 36 finished with value: 0.07470461028040179 and parameters: {'bagging_fraction': 0.9489111239527874, 'bagging_freq': 7}. Best is trial 33 with value: 0.0745454647646764.
# bagging, val_score: 0.074386: 100%|##########| 10/10 [11:59<00:00, 71.99s/it]
# feature_fraction_stage2, val_score: 0.074386:   0%|          | 0/3 [00:00<?, ?it/s]
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.009848 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 12637
# [LightGBM] [Info] Number of data points in the train set: 521580, number of used features: 21
# [LightGBM] [Info] Start training from score 7.219625
# Training until validation scores don't improve for 100 rounds
# [200]	valid_0's l1: 0.0754251
# [400]	valid_0's l1: 0.0748383
# [600]	valid_0's l1: 0.0746994
# [800]	valid_0's l1: 0.0746439
# Early stopping, best iteration is:
# [808]	valid_0's l1: 0.0746413
# feature_fraction_stage2, val_score: 0.074386:  33%|###3      | 1/3 [00:29<00:59, 29.66s/it][I 2021-05-27 13:15:20,817] Trial 37 finished with value: 0.0746413297259016 and parameters: {'feature_fraction': 0.44800000000000006}. Best is trial 37 with value: 0.0746413297259016.
# feature_fraction_stage2, val_score: 0.074386:  33%|###3      | 1/3 [00:29<00:59, 29.66s/it]
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.009514 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 12637
# [LightGBM] [Info] Number of data points in the train set: 521580, number of used features: 21
# [LightGBM] [Info] Start training from score 7.219625
# Training until validation scores don't improve for 100 rounds
# [200]	valid_0's l1: 0.0754251
# [400]	valid_0's l1: 0.0748383
# [600]	valid_0's l1: 0.0746994
# [800]	valid_0's l1: 0.0746439
# Early stopping, best iteration is:
# [808]	valid_0's l1: 0.0746413
# feature_fraction_stage2, val_score: 0.074386:  67%|######6   | 2/3 [00:58<00:29, 29.16s/it][I 2021-05-27 13:15:49,619] Trial 38 finished with value: 0.0746413297259016 and parameters: {'feature_fraction': 0.41600000000000004}. Best is trial 37 with value: 0.0746413297259016.
# feature_fraction_stage2, val_score: 0.074386:  67%|######6   | 2/3 [00:58<00:29, 29.16s/it]
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.010033 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 12637
# [LightGBM] [Info] Number of data points in the train set: 521580, number of used features: 21
# [LightGBM] [Info] Start training from score 7.219625
# Training until validation scores don't improve for 100 rounds
# [200]	valid_0's l1: 0.0751552
# [400]	valid_0's l1: 0.0747549
# [600]	valid_0's l1: 0.0746721
# [800]	valid_0's l1: 0.0746259
# Early stopping, best iteration is:
# [840]	valid_0's l1: 0.0746194
# feature_fraction_stage2, val_score: 0.074386: 100%|##########| 3/3 [01:30<00:00, 30.37s/it][I 2021-05-27 13:16:21,430] Trial 39 finished with value: 0.07461944365548387 and parameters: {'feature_fraction': 0.48000000000000004}. Best is trial 39 with value: 0.07461944365548387.
# feature_fraction_stage2, val_score: 0.074386: 100%|##########| 3/3 [01:30<00:00, 30.09s/it]
# regularization_factors, val_score: 0.074386:   0%|          | 0/20 [00:00<?, ?it/s]
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.008601 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 12637
# [LightGBM] [Info] Number of data points in the train set: 521580, number of used features: 21
# [LightGBM] [Info] Start training from score 7.219625
# Training until validation scores don't improve for 100 rounds
# [200]	valid_0's l1: 0.0753332
# [400]	valid_0's l1: 0.0747265
# [600]	valid_0's l1: 0.0744988
# [800]	valid_0's l1: 0.0744203
# [1000]	valid_0's l1: 0.074384
# Did not meet early stopping. Best iteration is:
# [985]	valid_0's l1: 0.0743784
# regularization_factors, val_score: 0.074378:   5%|5         | 1/20 [00:31<09:55, 31.35s/it][I 2021-05-27 13:16:52,780] Trial 40 finished with value: 0.07437835384812241 and parameters: {'lambda_l1': 3.474358123963195e-05, 'lambda_l2': 0.0009071876404259878}. Best is trial 40 with value: 0.07437835384812241.
# regularization_factors, val_score: 0.074378:   5%|5         | 1/20 [00:31<09:55, 31.35s/it]
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.010935 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 12637
# [LightGBM] [Info] Number of data points in the train set: 521580, number of used features: 21
# [LightGBM] [Info] Start training from score 7.219625
# Training until validation scores don't improve for 100 rounds
# [200]	valid_0's l1: 0.0753375
# [400]	valid_0's l1: 0.0747063
# [600]	valid_0's l1: 0.0745432
# [800]	valid_0's l1: 0.0744741
# [1000]	valid_0's l1: 0.0744011
# Did not meet early stopping. Best iteration is:
# [997]	valid_0's l1: 0.074399
# regularization_factors, val_score: 0.074378:  10%|#         | 2/20 [01:02<09:19, 31.11s/it][I 2021-05-27 13:17:23,729] Trial 41 finished with value: 0.07439901545547521 and parameters: {'lambda_l1': 2.526581322883229e-07, 'lambda_l2': 0.00016197930048948394}. Best is trial 40 with value: 0.07437835384812241.
# regularization_factors, val_score: 0.074378:  10%|#         | 2/20 [01:02<09:19, 31.11s/it]
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.009438 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 12637
# [LightGBM] [Info] Number of data points in the train set: 521580, number of used features: 21
# [LightGBM] [Info] Start training from score 7.219625
# Training until validation scores don't improve for 100 rounds
# [200]	valid_0's l1: 0.0753605
# [400]	valid_0's l1: 0.0747088
# [600]	valid_0's l1: 0.0744882
# [800]	valid_0's l1: 0.0744359
# [1000]	valid_0's l1: 0.0743998
# Did not meet early stopping. Best iteration is:
# [994]	valid_0's l1: 0.0743974
# regularization_factors, val_score: 0.074378:  15%|#5        | 3/20 [01:32<08:42, 30.73s/it][I 2021-05-27 13:17:54,003] Trial 42 finished with value: 0.07439739320185643 and parameters: {'lambda_l1': 5.3903997248590275e-05, 'lambda_l2': 0.00010252322532032779}. Best is trial 40 with value: 0.07437835384812241.
# regularization_factors, val_score: 0.074378:  15%|#5        | 3/20 [01:32<08:42, 30.73s/it]
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.009645 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 12637
# [LightGBM] [Info] Number of data points in the train set: 521580, number of used features: 21
# [LightGBM] [Info] Start training from score 7.219625
# Training until validation scores don't improve for 100 rounds
# [200]	valid_0's l1: 0.0754045
# [400]	valid_0's l1: 0.074803
# [600]	valid_0's l1: 0.074628
# [800]	valid_0's l1: 0.0745445
# [1000]	valid_0's l1: 0.0745167
# Did not meet early stopping. Best iteration is:
# [995]	valid_0's l1: 0.0745123
# regularization_factors, val_score: 0.074378:  20%|##        | 4/20 [02:03<08:15, 31.00s/it][I 2021-05-27 13:18:25,416] Trial 43 finished with value: 0.07451231701744986 and parameters: {'lambda_l1': 0.0030870877375526184, 'lambda_l2': 0.0034220609690211955}. Best is trial 40 with value: 0.07437835384812241.
# regularization_factors, val_score: 0.074378:  20%|##        | 4/20 [02:03<08:15, 31.00s/it]
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.009388 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 12637
# [LightGBM] [Info] Number of data points in the train set: 521580, number of used features: 21
# [LightGBM] [Info] Start training from score 7.219625
# Training until validation scores don't improve for 100 rounds
# [200]	valid_0's l1: 0.0754447
# [400]	valid_0's l1: 0.0747707
# [600]	valid_0's l1: 0.0745934
# [800]	valid_0's l1: 0.074497
# [1000]	valid_0's l1: 0.0744633
# Did not meet early stopping. Best iteration is:
# [956]	valid_0's l1: 0.0744603
# regularization_factors, val_score: 0.074378:  25%|##5       | 5/20 [02:35<07:48, 31.25s/it][I 2021-05-27 13:18:57,104] Trial 44 finished with value: 0.07446030163631949 and parameters: {'lambda_l1': 9.048498712130082e-05, 'lambda_l2': 2.851656930473058}. Best is trial 40 with value: 0.07437835384812241.
# regularization_factors, val_score: 0.074378:  25%|##5       | 5/20 [02:35<07:48, 31.25s/it]
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.009067 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 12637
# [LightGBM] [Info] Number of data points in the train set: 521580, number of used features: 21
# [LightGBM] [Info] Start training from score 7.219625
# Training until validation scores don't improve for 100 rounds
# [200]	valid_0's l1: 0.0753883
# [400]	valid_0's l1: 0.0746665
# [600]	valid_0's l1: 0.0744951
# [800]	valid_0's l1: 0.0744401
# [1000]	valid_0's l1: 0.0744072
# Did not meet early stopping. Best iteration is:
# [997]	valid_0's l1: 0.0744048
# regularization_factors, val_score: 0.074378:  30%|###       | 6/20 [03:08<07:23, 31.67s/it][I 2021-05-27 13:19:29,597] Trial 45 finished with value: 0.07440478830824418 and parameters: {'lambda_l1': 0.10890576651726831, 'lambda_l2': 0.9377235482218316}. Best is trial 40 with value: 0.07437835384812241.
# regularization_factors, val_score: 0.074378:  30%|###       | 6/20 [03:08<07:23, 31.67s/it]
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.009453 seconds.
# ...
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Early stopping, best iteration is:
# [807]	valid_0's l1: 0.0740215
# min_data_in_leaf, val_score: 0.074011:  60%|######    | 3/5 [01:56<01:18, 39.41s/it][I 2021-05-27 13:29:31,780] Trial 62 finished with value: 0.07402150076626357 and parameters: {'min_child_samples': 5}. Best is trial 62 with value: 0.07402150076626357.
# min_data_in_leaf, val_score: 0.074011:  60%|######    | 3/5 [01:56<01:18, 39.41s/it]
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.008973 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 12637
# [LightGBM] [Info] Number of data points in the train set: 521580, number of used features: 21
# [LightGBM] [Info] Start training from score 7.219625
# Training until validation scores don't improve for 100 rounds
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [200]	valid_0's l1: 0.0754085
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [400]	valid_0's l1: 0.0743759
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [600]	valid_0's l1: 0.0741778
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [800]	valid_0's l1: 0.0741229
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# Early stopping, best iteration is:
# [809]	valid_0's l1: 0.074105
# min_data_in_leaf, val_score: 0.074011:  80%|########  | 4/5 [02:38<00:40, 40.39s/it][I 2021-05-27 13:30:13,671] Trial 63 finished with value: 0.07410498223046355 and parameters: {'min_child_samples': 50}. Best is trial 62 with value: 0.07402150076626357.
# min_data_in_leaf, val_score: 0.074011:  80%|########  | 4/5 [02:38<00:40, 40.39s/it]
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.008996 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 12637
# [LightGBM] [Info] Number of data points in the train set: 521580, number of used features: 21
# [LightGBM] [Info] Start training from score 7.219625
# Training until validation scores don't improve for 100 rounds
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [200]	valid_0's l1: 0.0753779
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [400]	valid_0's l1: 0.074375
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [600]	valid_0's l1: 0.0741446
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Early stopping, best iteration is:
# [673]	valid_0's l1: 0.0740972
# min_data_in_leaf, val_score: 0.074011: 100%|##########| 5/5 [03:16<00:00, 39.48s/it][I 2021-05-27 13:30:51,537] Trial 64 finished with value: 0.07409722609981383 and parameters: {'min_child_samples': 25}. Best is trial 62 with value: 0.07402150076626357.
# min_data_in_leaf, val_score: 0.074011: 100%|##########| 5/5 [03:16<00:00, 39.29s/it]

# %%
best_params = opt.params
print(best_params)
# Out:
# {'objective': 'regression', 'metric': 'l1', 'feature_pre_filter': False, 'lambda_l1': 8.537307531902528, 'lambda_l2': 2.6165319905171392e-08, 'num_leaves': 113, 'feature_fraction': 0.4, 'bagging_fraction': 1.0, 'bagging_freq': 0, 'min_child_samples': 20, 'num_iterations': 1000, 'early_stopping_round': 100, 'categorical_column': [0, 1, 2, 3, 5, 8, 9, 10, 11, 15, 16]}

# %%
# lightGBM
import lightgbm as lgb

params = {
    "objective": "regression",
    "metrics": "mae", 
    "lambda_l1": 8.442195346804022,
    "lambda_l2": 5.708301125509865e-05,
    "num_leaves": 143,
    "feature_fraction": 0.484,
    "bagging_fraction": 1.0,
    "bagging_freq": 0,
    "min_child_samples": 50
}

model = lgb.train(best_params, trains, valid_sets=valids, num_boost_round=1000, early_stopping_rounds=100, verbose_eval=200)
# Out:
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:148: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning("Found `{}` in params. Will use it instead of argument".format(alias))
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:153: UserWarning: Found `early_stopping_round` in params. Will use it instead of argument
#   _log_warning("Found `{}` in params. Will use it instead of argument".format(alias))
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.010298 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 12637
# [LightGBM] [Info] Number of data points in the train set: 521580, number of used features: 21
# [LightGBM] [Info] Start training from score 7.219625
# Training until validation scores don't improve for 100 rounds
# [200]	valid_0's l1: 0.0753635
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [400]	valid_0's l1: 0.0743248
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [600]	valid_0's l1: 0.0740678
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Early stopping, best iteration is:
# [672]	valid_0's l1: 0.0740112

# %%
vals = model.predict(val_x)
mae(vals, val_y)
# Out:
# 0.07401120681222327

# %%
df_test = pd.read_csv("/tmp/working/dataset/nishika/old_apartment_2020/test.csv", index_col=0)
df_test = data_pre2(df_test)
predict = model.predict(df_test)
df_test["取引価格（総額）_log"] = predict
df_test[["取引価格（総額）_log"]].to_csv("./output/3_sub.csv")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-19-a3fea49ebb5b> in <module>
#       1 df_test = pd.read_csv("/tmp/working/dataset/nishika/old_apartment_2020/test.csv", index_col=0)
# ----> 2 df_test = data_pre2(df_test)
#       3 predict = model.predict(df_test)
#       4 df_test["取引価格（総額）_log"] = predict
#       5 df_test[["取引価格（総額）_log"]].to_csv("./output/3_sub.csv")
#
# <ipython-input-17-f3bbfd2017ec> in data_pre2(df)
#       4     df = data_pre(df)
#       5     df_b = df.copy()
# ----> 6     df = df[["都道府県名", "都道府県名_en", "市区町村名", "面積（㎡）", "取引価格（総額）_log"]]
#       7     pref_list = df["都道府県名"].tolist()
#       8     pref_list = set(pref_list)
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3028             if is_iterator(key):
#    3029                 key = list(key)
# -> 3030             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    3031
#    3032         # take() does not accept boolean indexers
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1264             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1265
# -> 1266         self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#    1267         return keyarr, indexer
#    1268
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1314             if raise_missing:
#    1315                 not_found = list(set(key) - set(ax))
# -> 1316                 raise KeyError(f"{not_found} not in index")
#    1317
#    1318             not_found = key[missing_mask]
#
# KeyError: "['取引価格（総額）_log'] not in index"

# %%
model = train(df)
# Out:
# [I 2021-05-27 12:08:43,035] A new study created in memory with name: no-name-de15a86a-65e5-4b9e-8a96-dcce8a6199e5
# feature_fraction, val_score: inf:   0%|          | 0/7 [00:00<?, ?it/s]/opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1433: UserWarning: Overriding the parameters from Reference Dataset.
#   _log_warning('Overriding the parameters from Reference Dataset.')
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1245: UserWarning: categorical_column in param dict is overridden.
#   _log_warning('{} in param dict is overridden.'.format(cat_alias))
# [LightGBM] [Warning] min_data_in_leaf is set=50, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=50
# [LightGBM] [Warning] min_data_in_leaf is set=50, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=50
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.003768 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 875
# [LightGBM] [Info] Number of data points in the train set: 521580, number of used features: 6
# [LightGBM] [Warning] min_data_in_leaf is set=50, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=50
# [LightGBM] [Info] Start training from score 7.219675
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Training until validation scores don't improve for 100 rounds
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [200]	valid_0's l1: 0.00354096
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [W 2021-05-27 12:08:49,716] Trial 0 failed because of the following error: KeyError('binary_logloss')
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/optuna/_optimize.py", line 217, in _run_trial
#     value_or_values = func(trial)
#   File "/opt/conda/lib/python3.7/site-packages/optuna/integration/_lightgbm_tuner/optimize.py", line 251, in __call__
#     val_score = self._get_booster_best_score(booster)
#   File "/opt/conda/lib/python3.7/site-packages/optuna/integration/_lightgbm_tuner/optimize.py", line 118, in _get_booster_best_score
#     val_score = booster.best_score[valid_name][metric]
# KeyError: 'binary_logloss'
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [400]	valid_0's l1: 0.00352011
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Early stopping, best iteration is:
# [308]	valid_0's l1: 0.00351902
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-10-9aa420752a53> in <module>
# ----> 1 model = train(df)
#
# /tmp/working/nishika/old_apartment_2020/m01_lightgbm.py in train(df)
#      31     }
#      32
# ---> 33     model = lgb.train(params, trains, valid_sets=valids, num_boost_round=1000, early_stopping_rounds=100, verbose_eval=200)
#      34
#      35     vals = model.predict(val_x)
#
# /opt/conda/lib/python3.7/site-packages/optuna/integration/_lightgbm_tuner/__init__.py in train(*args, **kwargs)
#      33
#      34     auto_booster = LightGBMTuner(*args, **kwargs)
# ---> 35     auto_booster.run()
#      36     return auto_booster.get_best_booster()
#
# /opt/conda/lib/python3.7/site-packages/optuna/integration/_lightgbm_tuner/optimize.py in run(self)
#     541         self.sample_train_set()
#     542
# --> 543         self.tune_feature_fraction()
#     544         self.tune_num_leaves()
#     545         self.tune_bagging()
#
# /opt/conda/lib/python3.7/site-packages/optuna/integration/_lightgbm_tuner/optimize.py in tune_feature_fraction(self, n_trials)
#     566
#     567         sampler = optuna.samplers.GridSampler({param_name: param_values})
# --> 568         self._tune_params([param_name], len(param_values), sampler, "feature_fraction")
#     569
#     570     def tune_num_leaves(self, n_trials: int = 20) -> None:
#
# /opt/conda/lib/python3.7/site-packages/optuna/integration/_lightgbm_tuner/optimize.py in _tune_params(self, target_param_names, n_trials, sampler, step_name)
#     646                 timeout=_timeout,
#     647                 catch=(),
# --> 648                 callbacks=self._optuna_callbacks,
#     649             )
#     650
#
# /opt/conda/lib/python3.7/site-packages/optuna/study.py in optimize(self, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     407             callbacks=callbacks,
#     408             gc_after_trial=gc_after_trial,
# --> 409             show_progress_bar=show_progress_bar,
#     410         )
#     411
#
# /opt/conda/lib/python3.7/site-packages/optuna/_optimize.py in _optimize(study, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#      74                 reseed_sampler_rng=False,
#      75                 time_start=None,
# ---> 76                 progress_bar=progress_bar,
#      77             )
#      78         else:
#
# /opt/conda/lib/python3.7/site-packages/optuna/_optimize.py in _optimize_sequential(study, func, n_trials, timeout, catch, callbacks, gc_after_trial, reseed_sampler_rng, time_start, progress_bar)
#     161
#     162         try:
# --> 163             trial = _run_trial(study, func, catch)
#     164         except Exception:
#     165             raise
#
# /opt/conda/lib/python3.7/site-packages/optuna/_optimize.py in _run_trial(study, func, catch)
#     266
#     267     if state == TrialState.FAIL and func_err is not None and not isinstance(func_err, catch):
# --> 268         raise func_err
#     269     return trial
#     270
#
# /opt/conda/lib/python3.7/site-packages/optuna/_optimize.py in _run_trial(study, func, catch)
#     215
#     216     try:
# --> 217         value_or_values = func(trial)
#     218     except exceptions.TrialPruned as e:
#     219         # TODO(mamu): Handle multi-objective cases.
#
# /opt/conda/lib/python3.7/site-packages/optuna/integration/_lightgbm_tuner/optimize.py in __call__(self, trial)
#     249         booster = lgb.train(self.lgbm_params, train_set, **kwargs)
#     250
# --> 251         val_score = self._get_booster_best_score(booster)
#     252         elapsed_secs = time.time() - start_time
#     253         average_iteration_time = elapsed_secs / booster.current_iteration()
#
# /opt/conda/lib/python3.7/site-packages/optuna/integration/_lightgbm_tuner/optimize.py in _get_booster_best_score(self, booster)
#     116             raise NotImplementedError
#     117
# --> 118         val_score = booster.best_score[valid_name][metric]
#     119         return val_score
#     120
#
# KeyError: 'binary_logloss'
