# %%
import glob
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import test_func as tf
# %matplotlib inline

# %%
files = glob.glob("/tmp/working/dataset/nishika/old_apartment/train/*.csv")
data_list = []
for file in files:
    data_list.append(pd.read_csv(file, index_col=0))
df = pd.concat(data_list)
# Out:
# /opt/conda/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df = tf.data_pre(df)
model = tf.model_lgb(df)
# Out:
# /opt/conda/lib/python3.6/site-packages/lightgbm/basic.py:762: UserWarning: categorical_feature in param dict is overridden.
#   warnings.warn('categorical_feature in param dict is overridden.')
# [1]	valid_0's l1: 0.253853
# Training until validation scores don't improve for 100 rounds.
# [2]	valid_0's l1: 0.23733
# [3]	valid_0's l1: 0.223018
# [4]	valid_0's l1: 0.210166
# [5]	valid_0's l1: 0.198689
# [6]	valid_0's l1: 0.188459
# [7]	valid_0's l1: 0.179716
# [8]	valid_0's l1: 0.171823
# [9]	valid_0's l1: 0.164789
# [10]	valid_0's l1: 0.158642
# [11]	valid_0's l1: 0.153085
# [12]	valid_0's l1: 0.148124
# [13]	valid_0's l1: 0.143733
# [14]	valid_0's l1: 0.13962
# [15]	valid_0's l1: 0.136094
# [16]	valid_0's l1: 0.132989
# [17]	valid_0's l1: 0.130186
# [18]	valid_0's l1: 0.127312
# [19]	valid_0's l1: 0.125071
# [20]	valid_0's l1: 0.122842
# [21]	valid_0's l1: 0.120713
# [22]	valid_0's l1: 0.11847
# [23]	valid_0's l1: 0.116703
# [24]	valid_0's l1: 0.11508
# [25]	valid_0's l1: 0.113668
# ...

# %%
def data_pre(df):
    nonnull_list = []

    for col in df.columns:
        nonnull = df[col].count()
        if nonnull == 0:
            nonnull_list.append(col)

    nonnull_list

    df = df.drop(nonnull_list, axis=1)

    df = df.drop("市区町村名", axis=1)

    df = df.drop("種類", axis=1)

    dis ={
        "30分?60分":45,
        "1H?1H30":75,
        "2H?":120,
        "1H30?2H":105,
    }

    df["最寄駅：距離（分）"] = df["最寄駅：距離（分）"].replace(dis).astype(float)

    df["面積（㎡）"] = df["面積（㎡）"].replace("2000㎡以上", 2000).astype(float)

    y_list = {}
    for i in  df["建築年"].value_counts().keys():
        if "平成" in i:
            num = i.split("平成")[1].split("年")[0]
            year = 33 - int(num)
        if "令和" in i:
            num = i.split("令和")[1].split("年")[0]
            year = 3 - int(num)
        if "昭和" in i:
            num = i.split("昭和")[1].split("年")[0]
            year = 96 - int(num)
        y_list[i] = year
    y_list["戦前"] = 76

    df["建築年"] = df["建築年"].replace(y_list)

    year = {
        "年第１四半期":".25",
        "年第２四半期":".50",
        "年第３四半期":".75",
        "年第４四半期":".99"
    }

    year_list = {}
    for i in df["取引時点"].value_counts().keys():
        for k, j in year.items():
            if k in i:
                year_rep = i.replace(k, j)

        year_list[i] = year_rep

    df["取引時点"] = df["取引時点"].replace(year_list).astype(float)
    
    for col in ["都道府県名", "地区名", "最寄駅：名称", "間取り", "建物の構造", "用途", "今後の利用目的", "都市計画", "改装", "取引の事情等"]:
        df[col] = df[col].astype("category")
    
    return df

# %%
df = data_pre(df)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 637351 entries, 1060685 to 47003572
# Data columns (total 18 columns):
# 市区町村コード         637351 non-null int64
# 都道府県名           637351 non-null category
# 地区名             637060 non-null category
# 最寄駅：名称          634732 non-null category
# 最寄駅：距離（分）       614306 non-null float64
# 間取り             615609 non-null category
# 面積（㎡）           637351 non-null float64
# 建築年             619117 non-null float64
# 建物の構造           623423 non-null category
# 用途              591214 non-null category
# 今後の利用目的         275091 non-null category
# 都市計画            618786 non-null category
# 建ぺい率（％）         614848 non-null float64
# 容積率（％）          614848 non-null float64
# 取引時点            637351 non-null float64
# 改装              580431 non-null category
# 取引の事情等          18275 non-null category
# 取引価格（総額）_log    637351 non-null float64
# dtypes: category(10), float64(7), int64(1)
# memory usage: 51.7 MB

# %%
import lightgbm as lgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error as mae

df_train, df_val = train_test_split(df, test_size=0.2)

col = "取引価格（総額）_log"
train_y = df_train[col]
train_x = df_train.drop(col, axis=1)

val_y = df_val[col]
val_x = df_val.drop(col, axis=1)

trains = lgb.Dataset(train_x, train_y)
valids = lgb.Dataset(val_x, val_y)

params = {
    "objective": "regression",
    "metrics": "mae"
}

modl = lgb.train(params, trains, valid_sets=valids, num_boost_round=1000, early_stopping_rounds=100)
# Out:
# /opt/conda/lib/python3.6/site-packages/lightgbm/basic.py:762: UserWarning: categorical_feature in param dict is overridden.
#   warnings.warn('categorical_feature in param dict is overridden.')
# [1]	valid_0's l1: 0.252905
# Training until validation scores don't improve for 100 rounds.
# [2]	valid_0's l1: 0.236564
# [3]	valid_0's l1: 0.22212
# [4]	valid_0's l1: 0.209373
# [5]	valid_0's l1: 0.198064
# [6]	valid_0's l1: 0.188205
# [7]	valid_0's l1: 0.179441
# [8]	valid_0's l1: 0.171546
# [9]	valid_0's l1: 0.164504
# [10]	valid_0's l1: 0.158248
# [11]	valid_0's l1: 0.152972
# [12]	valid_0's l1: 0.148058
# [13]	valid_0's l1: 0.143664
# [14]	valid_0's l1: 0.139559
# [15]	valid_0's l1: 0.136008
# [16]	valid_0's l1: 0.13288
# [17]	valid_0's l1: 0.129844
# [18]	valid_0's l1: 0.127282
# [19]	valid_0's l1: 0.124904
# [20]	valid_0's l1: 0.122738
# [21]	valid_0's l1: 0.120613
# [22]	valid_0's l1: 0.118679
# [23]	valid_0's l1: 0.117136
# [24]	valid_0's l1: 0.115396
# [25]	valid_0's l1: 0.113821
# ...

# %%
vals = modl.predict(val_x)
mae(vals, val_y)
# Out:
# 0.07678097088786548

# %%
df_test = pd.read_csv("/tmp/working/dataset/nishika/old_apartment/test.csv", index_col=0)
df_test = data_pre(df_test)

# %%
df_test.head()
# Out:
#          市区町村コード 都道府県名  地区名 最寄駅：名称   ...    容積率（％）     取引時点   改装  取引の事情等
# ID                                   ...
# 1000000     1101   北海道  旭ケ丘   円山公園   ...      60.0  2020.50  未改装     NaN
# 1000056     1101   北海道  大通西  西１１丁目   ...     600.0  2020.25  未改装     NaN
# 1000108     1101   北海道  大通西  西１８丁目   ...     400.0  2020.50  未改装     NaN
# 1000109     1101   北海道  大通西  西１８丁目   ...     400.0  2020.50  改装済     NaN
# 1000110     1101   北海道  大通西  西１８丁目   ...     400.0  2020.50  NaN     NaN
#
# [5 rows x 17 columns]

# %%
predict = modl.predict(df_test)
df_test["取引価格（総額）_log"] = predict

# %%
df_test.head()
# Out:
#          市区町村コード 都道府県名  地区名     ...        改装  取引の事情等 取引価格（総額）_log
# ID                              ...
# 1000000     1101   北海道  旭ケ丘     ...       未改装     NaN     7.076144
# 1000056     1101   北海道  大通西     ...       未改装     NaN     7.597076
# 1000108     1101   北海道  大通西     ...       未改装     NaN     6.518893
# 1000109     1101   北海道  大通西     ...       改装済     NaN     7.105128
# 1000110     1101   北海道  大通西     ...       NaN     NaN     6.510844
#
# [5 rows x 18 columns]

# %%
df_test[["取引価格（総額）_log"]].to_csv("submit_test.csv")

# %%
pd.DataFrame(modl.feature_importance(), index=val_x.columns, columns=["importance"]).sort_values("importance", ascending=False)
# Out:
#            importance
# 地区名              8770
# 最寄駅：名称           6633
# 建築年              3327
# 取引時点             3127
# 面積（㎡）            2137
# 最寄駅：距離（分）        1921
# 間取り               823
# 市区町村コード           662
# 都道府県名             592
# 改装                503
# 容積率（％）            400
# 都市計画              347
# 建ぺい率（％）           205
# 取引の事情等            153
# 用途                120
# 今後の利用目的            97
# 建物の構造              93
